# %%
# Импорт библиотек
import cv2
import numpy as np
from matplotlib import pyplot as plt
# Загрузим шаблоны для мемов (картинки)
imgloc = (r"C:\Users\Dauren\PycharmProjects\Anime\Anime.jpg")
imgloc_1 = (r"C:\Users\Dauren\PycharmProjects\Anime\Drake1.jpg")
imgloc_2 = (r"C:\Users\Dauren\PycharmProjects\Anime\Drake2.jpg")
img = cv2.imread(imgloc)
img_RGB = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img_1 = cv2.imread(imgloc_1)
img_1_RGB = cv2.cvtColor(img_1,cv2.COLOR_BGR2RGB)
img_2 = cv2.imread(imgloc_2)
img_2_RGB = cv2.cvtColor(img_2,cv2.COLOR_BGR2RGB)
# Задаем ядро (фильтр)
Kernel = 1/3*np.array([[-0.1, 0.1, -0.1],
[0.1, 0.5, 0.1],
[-0.1, 0.1, -0.1]])
# Применяем Filter2D
filtered = cv2.filter2D(img_RGB, -1, Kernel)
# Кадр №1
plt.subplot(121), plt.imshow(img_RGB), plt.title('Здравствуйте. Я хочу \n  получить "+" \n за практику')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(img_1_RGB), plt.title('Иди отсюда, мальчик')
plt.xticks([]), plt.yticks([])
plt.show()
# Кадр №2
plt.subplot(121), plt.imshow(filtered), plt.title('*выключает свет* \n А так?')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(img_2_RGB), plt.title('Ладно. Какая у Вас \n фамилия?')
plt.xticks([]), plt.yticks([])
plt.show()
